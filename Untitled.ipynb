# %%
import pandas as pd

# %%
frame = pd.DataFrame({'numbers':range(10),'chars':['a']*10})

# %%
frame
# Out:
#    numbers chars
# 0        0     a
# 1        1     a
# 2        2     a
# 3        3     a
# 4        4     a
# 5        5     a
# 6        6     a
# 7        7     a
# 8        8     a
# 9        9     a

# %%
frame = pd.read_csv('dataset.tsv', header = 0, sep = '\t')

# %%
frame
# Out:
#               Name       Birth       City  Position
# 0      Иванов А.А.  22.03.1980     Москва       NaN
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер
# 2       Белов М.М.  13.02.1980     Ростов  менеджер
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер
# 5     Костров С.О.  31.05.1985     Москва    стажер

# %%
frame.columns
# Out:
# Index(['Name', 'Birth', 'City', 'Position'], dtype='object')

# %%
frame.shape
# Out:
# (6, 4)

# %%
new_line = {'Name':'Perov','Birth':'22.03.1990','City':'Penza'}

# %%
frame = frame.append(new_line, ignore_index = True)

# %%
frame
# Out:
#               Name       Birth       City  Position
# 0      Иванов А.А.  22.03.1980     Москва       NaN
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер
# 2       Белов М.М.  13.02.1980     Ростов  менеджер
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер
# 5     Костров С.О.  31.05.1985     Москва    стажер
# 6            Perov  22.03.1990      Penza       NaN

# %%
frame['IsStudent'] = [False]*5 + [True]*2

# %%
frame
# Out:
#               Name       Birth       City  Position  IsStudent
# 0      Иванов А.А.  22.03.1980     Москва       NaN      False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер      False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер      False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN      False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер      False
# 5     Костров С.О.  31.05.1985     Москва    стажер       True
# 6            Perov  22.03.1990      Penza       NaN       True

# %%
frame['Name']
# Out:
# 0        Иванов А.А.
# 1       Сорокин И.В.
# 2         Белов М.М.
# 3    Мельникова Д.С.
# 4        Рыбина Е.П.
# 5       Костров С.О.
# 6              Perov
# Name: Name, dtype: object

# %%
job = 'Employee'

# %%
frame
# Out:
#               Name       Birth       City  Position  IsStudent
# 0      Иванов А.А.  22.03.1980     Москва       NaN      False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер      False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер      False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN      False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер      False
# 5     Костров С.О.  31.05.1985     Москва    стажер       True
# 6            Perov  22.03.1990      Penza       NaN       True

# %%
frame['job']=[False] * 5 + [True] * 2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-7f548fb5dea3> in <module>
# ----> 1 frame['job']=[False] * 5 + [True] * 2
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3628
#    3629             # turn me into an ndarray
# ...

# %%
frame
# Out:
#               Name       Birth       City  Position  IsStudent    job
# 0      Иванов А.А.  22.03.1980     Москва       NaN      False  False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер      False  False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер      False  False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN      False  False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер      False  False
# 5     Костров С.О.  31.05.1985     Москва    стажер       True   True
# 6            Perov  22.03.1990      Penza       NaN       True   True

# %%
frame['employee'] = [False] * 5 + [True] * 2

# %%
frame
# Out:
#               Name       Birth       City  Position  IsStudent    job  \
# 0      Иванов А.А.  22.03.1980     Москва       NaN      False  False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер      False  False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер      False  False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN      False  False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер      False  False
# 5     Костров С.О.  31.05.1985     Москва    стажер       True   True
# 6            Perov  22.03.1990      Penza       NaN       True   True
#
#    employee
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True

# %%
frame['job kz'] = [False] * 5 + [True] * 2

# %%
frame
# Out:
#               Name       Birth       City  Position  IsStudent    job  \
# 0      Иванов А.А.  22.03.1980     Москва       NaN      False  False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер      False  False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер      False  False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN      False  False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер      False  False
# 5     Костров С.О.  31.05.1985     Москва    стажер       True   True
# 6            Perov  22.03.1990      Penza       NaN       True   True
#
#    employee  job kz
# 0     False   False
# 1     False   False
# 2     False   False
# 3     False   False
# 4     False   False
# 5      True    True
# 6      True    True

# %%
frame.drop([5,6],axis=0)
# Out:
#               Name       Birth       City  Position  IsStudent    job  \
# 0      Иванов А.А.  22.03.1980     Москва       NaN      False  False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер      False  False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер      False  False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN      False  False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер      False  False
#
#    employee  job kz
# 0     False   False
# 1     False   False
# 2     False   False
# 3     False   False
# 4     False   False

# %%
frame
# Out:
#               Name       Birth       City  Position  IsStudent    job  \
# 0      Иванов А.А.  22.03.1980     Москва       NaN      False  False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер      False  False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер      False  False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN      False  False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер      False  False
# 5     Костров С.О.  31.05.1985     Москва    стажер       True   True
# 6            Perov  22.03.1990      Penza       NaN       True   True
#
#    employee  job kz
# 0     False   False
# 1     False   False
# 2     False   False
# 3     False   False
# 4     False   False
# 5      True    True
# 6      True    True

# %%
frame.drop([5,6],axis=0, inplace = True)

# %%
frame
# Out:
#               Name       Birth       City  Position  IsStudent    job  \
# 0      Иванов А.А.  22.03.1980     Москва       NaN      False  False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер      False  False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер      False  False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN      False  False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер      False  False
#
#    employee  job kz
# 0     False   False
# 1     False   False
# 2     False   False
# 3     False   False
# 4     False   False

# %%
frame.drop('IsStudent', axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-21c47111c261> in <module>
# ----> 1 frame.drop('IsStudent', axis = 1, inplace = True)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
frame
# Out:
#               Name       Birth       City  Position    job  employee  job kz
# 0      Иванов А.А.  22.03.1980     Москва       NaN  False     False   False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер  False     False   False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер  False     False   False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN  False     False   False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер  False     False   False

# %%
frame
# Out:
#               Name       Birth       City  Position    job  employee
# 0      Иванов А.А.  22.03.1980     Москва       NaN  False     False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер  False     False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер  False     False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN  False     False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер  False     False

# %%
frame = frame.drop('job kz', axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-05f9897a9b73> in <module>
# ----> 1 frame = frame.drop('job kz', axis = 1)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
frame
# Out:
#               Name       Birth       City  Position    job  employee
# 0      Иванов А.А.  22.03.1980     Москва       NaN  False     False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер  False     False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер  False     False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN  False     False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер  False     False

# %%
frame
# Out:
#               Name       Birth       City  Position    job  employee
# 0      Иванов А.А.  22.03.1980     Москва       NaN  False     False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер  False     False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер  False     False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN  False     False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер  False     False

# %%
frame['trial'] = [True]*5

# %%
frame
# Out:
#               Name       Birth       City  Position    job  employee  trial
# 0      Иванов А.А.  22.03.1980     Москва       NaN  False     False   True
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер  False     False   True
# 2       Белов М.М.  13.02.1980     Ростов  менеджер  False     False   True
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN  False     False   True
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер  False     False   True

# %%
frame = frame.drop('trial', axis = 1)

# %%
frame
# Out:
#               Name       Birth       City  Position    job  employee
# 0      Иванов А.А.  22.03.1980     Москва       NaN  False     False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер  False     False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер  False     False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN  False     False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер  False     False

# %%
#pd.read.csv
#pd.read.excel

#pd.to_csv
#pd.to_csv

# %%
frame.to_csv('dataset/updated_dataset.csv', sep = ',', header = True, index = False)

# %%
frame
# Out:
#               Name       Birth       City  Position    job  employee
# 0      Иванов А.А.  22.03.1980     Москва       NaN  False     False
# 1     Сорокин И.В.  07.08.1965  Волгоград   инженер  False     False
# 2       Белов М.М.  13.02.1980     Ростов  менеджер  False     False
# 3  Мельникова Д.С.  15.04.1985     Ростов       NaN  False     False
# 4      Рыбина Е.П.  19.11.1985     Москва   инженер  False     False

# %%
frame.dtypes
# Out:
# Name        object
# Birth       object
# City        object
# Position    object
# job           bool
# employee      bool
# dtype: object

# %%
frame.Birth = frame.Birth.apply(pd.to_datetime)

# %%
frame
# Out:
#               Name      Birth       City  Position    job  employee
# 0      Иванов А.А. 1980-03-22     Москва       NaN  False     False
# 1     Сорокин И.В. 1965-07-08  Волгоград   инженер  False     False
# 2       Белов М.М. 1980-02-13     Ростов  менеджер  False     False
# 3  Мельникова Д.С. 1985-04-15     Ростов       NaN  False     False
# 4      Рыбина Е.П. 1985-11-19     Москва   инженер  False     False

# %%
frame.dtypes
# Out:
# Name                object
# Birth       datetime64[ns]
# City                object
# Position            object
# job                   bool
# employee              bool
# dtype: object

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 6 columns):
# Name        5 non-null object
# Birth       5 non-null datetime64[ns]
# City        5 non-null object
# Position    3 non-null object
# job         5 non-null bool
# employee    5 non-null bool
# dtypes: bool(2), datetime64[ns](1), object(3)
# memory usage: 210.0+ bytes

# %%
frame.fillna('разнарабочий')
# Out:
#               Name      Birth       City      Position    job  employee
# 0      Иванов А.А. 1980-03-22     Москва  разнарабочий  False     False
# 1     Сорокин И.В. 1965-07-08  Волгоград       инженер  False     False
# 2       Белов М.М. 1980-02-13     Ростов      менеджер  False     False
# 3  Мельникова Д.С. 1985-04-15     Ростов  разнарабочий  False     False
# 4      Рыбина Е.П. 1985-11-19     Москва       инженер  False     False

# %%
frame.fillna('разнарабочий', inplace = True)

# %%
frame
# Out:
#               Name      Birth       City      Position    job  employee
# 0      Иванов А.А. 1980-03-22     Москва  разнарабочий  False     False
# 1     Сорокин И.В. 1965-07-08  Волгоград       инженер  False     False
# 2       Белов М.М. 1980-02-13     Ростов      менеджер  False     False
# 3  Мельникова Д.С. 1985-04-15     Ростов  разнарабочий  False     False
# 4      Рыбина Е.П. 1985-11-19     Москва       инженер  False     False

# %%
frame.Position
# Out:
# 0    разнарабочий
# 1         инженер
# 2        менеджер
# 3    разнарабочий
# 4         инженер
# Name: Position, dtype: object

# %%
frame[['Name','Position']]
# Out:
#               Name      Position
# 0      Иванов А.А.  разнарабочий
# 1     Сорокин И.В.       инженер
# 2       Белов М.М.      менеджер
# 3  Мельникова Д.С.  разнарабочий
# 4      Рыбина Е.П.       инженер

# %%
frame[:3]
# Out:
#            Name      Birth       City      Position    job  employee
# 0   Иванов А.А. 1980-03-22     Москва  разнарабочий  False     False
# 1  Сорокин И.В. 1965-07-08  Волгоград       инженер  False     False
# 2    Белов М.М. 1980-02-13     Ростов      менеджер  False     False

# %%
frame.head(1)
# Out:
#           Name      Birth    City      Position    job  employee
# 0  Иванов А.А. 1980-03-22  Москва  разнарабочий  False     False

# %%
frame.tail(3)
# Out:
#               Name      Birth    City      Position    job  employee
# 2       Белов М.М. 1980-02-13  Ростов      менеджер  False     False
# 3  Мельникова Д.С. 1985-04-15  Ростов  разнарабочий  False     False
# 4      Рыбина Е.П. 1985-11-19  Москва       инженер  False     False

# %%
frame[-3:]
# Out:
#               Name      Birth    City      Position    job  employee
# 2       Белов М.М. 1980-02-13  Ростов      менеджер  False     False
# 3  Мельникова Д.С. 1985-04-15  Ростов  разнарабочий  False     False
# 4      Рыбина Е.П. 1985-11-19  Москва       инженер  False     False

# %%
frame.loc[[0,1,2],['Name','City']]
# Out:
#            Name       City
# 0   Иванов А.А.     Москва
# 1  Сорокин И.В.  Волгоград
# 2    Белов М.М.     Ростов

# %%
frame
# Out:
#               Name      Birth       City      Position    job  employee
# 0      Иванов А.А. 1980-03-22     Москва  разнарабочий  False     False
# 1     Сорокин И.В. 1965-07-08  Волгоград       инженер  False     False
# 2       Белов М.М. 1980-02-13     Ростов      менеджер  False     False
# 3  Мельникова Д.С. 1985-04-15     Ростов  разнарабочий  False     False
# 4      Рыбина Е.П. 1985-11-19     Москва       инженер  False     False

# %%
frame.iloc[[1,3,4],[0,1]]
# Out:
#               Name      Birth
# 1     Сорокин И.В. 1965-07-08
# 3  Мельникова Д.С. 1985-04-15
# 4      Рыбина Е.П. 1985-11-19

# %%
frame[frame.Birth >= pd.datetime(1985,1,1)]
# Out:
#               Name      Birth    City      Position    job  employee
# 3  Мельникова Д.С. 1985-04-15  Ростов  разнарабочий  False     False
# 4      Рыбина Е.П. 1985-11-19  Москва       инженер  False     False

# %%
frame[(frame.Birth >= pd.datetime(1985,1,1)) | (frame.City != 'Москва')]
# Out:
#               Name      Birth       City      Position    job  employee
# 1     Сорокин И.В. 1965-07-08  Волгоград       инженер  False     False
# 2       Белов М.М. 1980-02-13     Ростов      менеджер  False     False
# 3  Мельникова Д.С. 1985-04-15     Ростов  разнарабочий  False     False
# 4      Рыбина Е.П. 1985-11-19     Москва       инженер  False     False

# %%
frame[(frame.Birth >= pd.datetime(1985,1,1)) & (frame.City != 'Москва')]
# Out:
#               Name      Birth    City      Position    job  employee
# 3  Мельникова Д.С. 1985-04-15  Ростов  разнарабочий  False     False

# %%
frame1 = frame[(frame.Birth >= pd.datetime(1985,1,1)) | (frame.City != 'Москва')]

# %%
frame1
# Out:
#               Name      Birth       City      Position    job  employee
# 1     Сорокин И.В. 1965-07-08  Волгоград       инженер  False     False
# 2       Белов М.М. 1980-02-13     Ростов      менеджер  False     False
# 3  Мельникова Д.С. 1985-04-15     Ростов  разнарабочий  False     False
# 4      Рыбина Е.П. 1985-11-19     Москва       инженер  False     False

# %%
frame1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-27e14efc36ab> in <module>
# ----> 1 frame1
#
# NameError: name 'frame1' is not defined
